# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import tqdm
import random
import glob
import json
import networkx as nx

# %%
ZAPPOS_ROOT = '/home/amrith/zappos-50k/'
ZAPPOS_IMAGES_ROOT = '/home/amrith/zappos-50k/ut-zap50k-images-square'

# %%
df = pd.read_csv(f'{ZAPPOS_ROOT}/ut-zap50k-data/meta-data-bin.csv')
df['HeelHeight.High.heel'] = df['HeelHeight.4in...4.3.4in'] + df['HeelHeight.5in...over']
df['HeelHeight.Short.heel'] = df['HeelHeight.Flat'] + df['HeelHeight.Under.1in'] + df['HeelHeight.1in...1.3.4in']

# %%
df.shape
# Out:
# (50025, 154)

# %%
print(sorted(df.columns))
# Out:
# ['CID', 'Category.Boots', 'Category.Sandals', 'Category.Shoes', 'Category.Slippers', 'Closure.Adjustable', 'Closure.Ankle.Strap', 'Closure.Ankle.Wrap', 'Closure.Belt', 'Closure.Buckle', 'Closure.Bungee', 'Closure.Button.Loop', 'Closure.Elastic.Gore', 'Closure.Hook.and.Loop', 'Closure.Lace.up', 'Closure.Monk.Strap', 'Closure.Pull.on', 'Closure.Sling.Back', 'Closure.Slip.On', 'Closure.Snap', 'Closure.Spat.Strap', 'Closure.T.Strap', 'Closure.Toggle', 'Closure.Zipper', 'Gender.Boys', 'Gender.Girls', 'Gender.Men', 'Gender.Women', 'HeelHeight.1in...1.3.4in', 'HeelHeight.2in...2.3.4in', 'HeelHeight.3in...3.3.4in', 'HeelHeight.4in...4.3.4in', 'HeelHeight.5in...over', 'HeelHeight.Flat', 'HeelHeight.High.heel', 'HeelHeight.Short.heel', 'HeelHeight.Under.1in', 'Insole.EVA', 'Insole.Gel', 'Insole.Hypoallergenic', 'Insole.Latex.Lined', 'Insole.Leather', 'Insole.Memory.Foam', 'Insole.Moisture.Wicking', 'Insole.Orthotic.Friendly', 'Insole.Padded', 'Insole.Polyurethane', 'Insole.Poron', 'Insole.Removable', 'Insole.Synthetic.Leather', 'Insole.Textile', 'Material.Acrylic', 'Material.Aluminum', 'Material.Cable.Knit', 'Material.Canvas', 'Material.Cashmere', 'Material.Chiffon', 'Material.Cordura', 'Material.Corduroy', 'Material.Cork', 'Material.Cotton', 'Material.Crochet', 'Material.Crocodile', 'Material.Deerskin', 'Material.Denim', 'Material.Distressed.Leather', 'Material.EVA', 'Material.Exotic', 'Material.Faux.Fur', 'Material.Faux.Leather', 'Material.Faux.Suede', 'Material.Felt', 'Material.Fleece', 'Material.Full.grain.leather', 'Material.Hair.Calf', 'Material.Hemp', 'Material.Horse.Hair', 'Material.Jacquard', 'Material.Jute', 'Material.Lace', 'Material.Lambskin', 'Material.Latex', 'Material.Leather', 'Material.Linen', 'Material.Lizard', 'Material.Mesh', 'Material.Microfiber', 'Material.Nappa', 'Material.Neoprene', 'Material.Nubuck', 'Material.Nylon', 'Material.Ostrich', 'Material.Patent.Leather', 'Material.Plastic', 'Material.Polyester', 'Material.Polyurethane', 'Material.Raffia', 'Material.Ripstop', 'Material.Rubber', 'Material.Satin', 'Material.Shearling', 'Material.Sheepskin', 'Material.Silk', 'Material.Snakeskin', 'Material.Steel', 'Material.Stingray', 'Material.Suede', 'Material.Synthetic', 'Material.Terry', 'Material.Tweed', 'Material.Velour', 'Material.Velvet', 'Material.Vinyl', 'Material.Wool', 'SubCategory.Ankle', 'SubCategory.Athletic', 'SubCategory.Boat.Shoes', 'SubCategory.Boot', 'SubCategory.Clogs.and.Mules', 'SubCategory.Crib.Shoes', 'SubCategory.Firstwalker', 'SubCategory.Flat', 'SubCategory.Flats', 'SubCategory.Heel', 'SubCategory.Heels', 'SubCategory.Knee.High', 'SubCategory.Loafers', 'SubCategory.Mid.Calf', 'SubCategory.Over.the.Knee', 'SubCategory.Oxfords', 'SubCategory.Prewalker', 'SubCategory.Prewalker.Boots', 'SubCategory.Slipper.Flats', 'SubCategory.Slipper.Heels', 'SubCategory.Sneakers.and.Athletic.Shoes', 'ToeStyle.Algonquin', 'ToeStyle.Almond', 'ToeStyle.Apron Toe', 'ToeStyle.Bicycle Toe', 'ToeStyle.Bump Toe', 'ToeStyle.Capped Toe', 'ToeStyle.Center Seam', 'ToeStyle.Closed Toe', 'ToeStyle.Medallion', 'ToeStyle.Moc Toe', 'ToeStyle.Open Toe', 'ToeStyle.Peep Toe', 'ToeStyle.Pointed Toe', 'ToeStyle.Round Toe', 'ToeStyle.Snip Toe', 'ToeStyle.Snub Toe', 'ToeStyle.Square Toe', 'ToeStyle.Wide Toe Box', 'ToeStyle.Wingtip']

# %%
# Attribute list
ATTR_LIST_1 = ['Category.Shoes', 'Category.Sandals', 'SubCategory.Oxfords', 'SubCategory.Heel', 'SubCategory.Boot', 'SubCategory.Slipper.Flats', 'SubCategory.Flats', 'SubCategory.Slipper.Heels', 'SubCategory.Athletic', 'SubCategory.Knee.High', 'SubCategory.Crib.Shoes', 'SubCategory.Over.the.Knee', 'HeelHeight.High.heel', 'HeelHeight.Short.heel', 'Closure.Pull.on', 'Closure.Ankle.Strap', 'Closure.Zipper', 'Closure.Elastic.Gore', 'Closure.Sling.Back', 'Closure.Toggle', 'Closure.Snap', 'Closure.T.Strap', 'Closure.Spat.Strap', 'Gender.Men', 'Gender.Boys', 'Material.Rubber', 'Material.Wool', 'Material.Silk', 'Material.Aluminum', 'Material.Plastic', 'ToeStyle.Capped Toe', 'ToeStyle.Square Toe', 'ToeStyle.Snub Toe', 'ToeStyle.Bicycle Toe', 'ToeStyle.Open Toe', 'ToeStyle.Pointed Toe', 'ToeStyle.Almond', 'ToeStyle.Apron Toe', 'ToeStyle.Snip Toe', 'ToeStyle.Medallion']
ATTR_LIST_2 = ['Category.Boots', 'Category.Slippers', 'SubCategory.Mid.Calf', 'SubCategory.Ankle', 'SubCategory.Loafers', 'SubCategory.Boat.Shoes', 'SubCategory.Clogs.and.Mules', 'SubCategory.Sneakers.and.Athletic.Shoes', 'SubCategory.Heels', 'SubCategory.Prewalker', 'SubCategory.Prewalker.Boots', 'SubCategory.Firstwalker', 'Closure.Lace.up', 'Closure.Buckle', 'Closure.Hook.and.Loop', 'Closure.Slip.On', 'Closure.Ankle.Wrap', 'Closure.Bungee', 'Closure.Adjustable',  'Closure.Button.Loop', 'Closure.Monk.Strap', 'Closure.Belt', 'Gender.Women', 'Gender.Girls', 'Material.Suede', 'Material.Snakeskin', 'Material.Corduroy', 'Material.Horse.Hair', 'Material.Stingray', 'ToeStyle.Round Toe', 'ToeStyle.Closed Toe', 'ToeStyle.Moc Toe', 'ToeStyle.Wingtip', 'ToeStyle.Center Seam', 'ToeStyle.Algonquin', 'ToeStyle.Bump Toe', 'ToeStyle.Wide Toe Box', 'ToeStyle.Peep Toe']
FULL_ATTR_LIST = sorted(list(set(ATTR_LIST_1 + ATTR_LIST_2)))
for x in FULL_ATTR_LIST:
    if x not in df.columns: 
        print(x)
print(len(FULL_ATTR_LIST))
# Out:
# 78

# %%
for a, x in zip(FULL_ATTR_LIST, df.loc[:, FULL_ATTR_LIST].apply(sum, axis=0)):
    print(f'{a} \t\t {x}')
# Out:
# Category.Boots 		 12832
# Category.Sandals 		 5741
# Category.Shoes 		 30169
# Category.Slippers 		 1283
# Closure.Adjustable 		 1
# Closure.Ankle.Strap 		 1425
# Closure.Ankle.Wrap 		 102
# Closure.Belt 		 8
# Closure.Buckle 		 3648
# Closure.Bungee 		 640
# Closure.Button.Loop 		 111
# Closure.Elastic.Gore 		 1741
# Closure.Hook.and.Loop 		 4853
# Closure.Lace.up 		 16221
# Closure.Monk.Strap 		 84
# Closure.Pull.on 		 4618
# Closure.Sling.Back 		 482
# Closure.Slip.On 		 15725
# Closure.Snap 		 70
# Closure.Spat.Strap 		 20
# Closure.T.Strap 		 28
# Closure.Toggle 		 410
# Closure.Zipper 		 5063
# Gender.Boys 		 4495
# Gender.Girls 		 6550
# Gender.Men 		 13337
# Gender.Women 		 28188
# HeelHeight.High.heel 		 3527
# HeelHeight.Short.heel 		 19605
# Material.Aluminum 		 14
# Material.Corduroy 		 68
# Material.Horse.Hair 		 4
# Material.Plastic 		 3
# Material.Rubber 		 6830
# Material.Silk 		 28
# Material.Snakeskin 		 13
# Material.Stingray 		 4
# Material.Suede 		 8222
# Material.Wool 		 434
# SubCategory.Ankle 		 5855
# SubCategory.Athletic 		 14
# SubCategory.Boat.Shoes 		 629
# SubCategory.Boot 		 14
# SubCategory.Clogs.and.Mules 		 1427
# SubCategory.Crib.Shoes 		 23
# SubCategory.Firstwalker 		 369
# SubCategory.Flats 		 3994
# SubCategory.Heel 		 126
# SubCategory.Heels 		 5703
# SubCategory.Knee.High 		 2202
# SubCategory.Loafers 		 2875
# SubCategory.Mid.Calf 		 4724
# SubCategory.Over.the.Knee 		 49
# SubCategory.Oxfords 		 2044
# SubCategory.Prewalker 		 249
# SubCategory.Prewalker.Boots 		 2
# SubCategory.Slipper.Flats 		 1259
# SubCategory.Slipper.Heels 		 10
# SubCategory.Sneakers.and.Athletic.Shoes 		 12856
# ToeStyle.Algonquin 		 89
# ToeStyle.Almond 		 1502
# ToeStyle.Apron Toe 		 52
# ToeStyle.Bicycle Toe 		 288
# ToeStyle.Bump Toe 		 829
# ToeStyle.Capped Toe 		 1944
# ToeStyle.Center Seam 		 475
# ToeStyle.Closed Toe 		 19896
# ToeStyle.Medallion 		 155
# ToeStyle.Moc Toe 		 2842
# ToeStyle.Open Toe 		 5296
# ToeStyle.Peep Toe 		 1442
# ToeStyle.Pointed Toe 		 1277
# ToeStyle.Round Toe 		 21327
# ToeStyle.Snip Toe 		 441
# ToeStyle.Snub Toe 		 359
# ToeStyle.Square Toe 		 810
# ToeStyle.Wide Toe Box 		 186
# ToeStyle.Wingtip 		 712

# %%
def is_same_category(attrs):
    return len(set([attr.lower().split(".")[0] for attr in attrs])) < len(attrs)
    
def get_all_positive_images(df, attrs):
    return df[attrs].apply(sum, axis=1) == len(attrs)

# %%
from tqdm import tqdm
import concurrent.futures
from multiprocessing import Pool

attr_pairs = []
for i in range(len(FULL_ATTR_LIST)):        
    for j in range(i+1, len(FULL_ATTR_LIST)):
        attrs = sorted([FULL_ATTR_LIST[i], FULL_ATTR_LIST[j]]) # sort to fix key for pair of attrs
        attr_pairs.append(attrs)

print(len(attr_pairs)) # list of all attr pairs

def get_positive_images_count(attrs):
    if is_same_category(attrs):
        return 0 # same category => 0 weight
    else:
        return get_all_positive_images(df, attrs).sum()

pool = Pool() 
counts = pool.map(get_positive_images_count, attr_pairs)

attr_pair_weight = defaultdict(int)
for a_pair, cnt in zip(attr_pairs, counts):
    attr_pair_weight[";".join(a_pair)] = cnt
# Out:
# 3003

# %%
attr_pair_weight
# Out:
# defaultdict(int,
#             {'Category.Boots;Category.Sandals': 0,
#              'Category.Boots;Category.Shoes': 0,
#              'Category.Boots;Category.Slippers': 0,
#              'Category.Boots;Closure.Adjustable': 0,
#              'Category.Boots;Closure.Ankle.Strap': 0,
#              'Category.Boots;Closure.Ankle.Wrap': 0,
#              'Category.Boots;Closure.Belt': 8,
#              'Category.Boots;Closure.Buckle': 370,
#              'Category.Boots;Closure.Bungee': 248,
#              'Category.Boots;Closure.Button.Loop': 82,
#              'Category.Boots;Closure.Elastic.Gore': 473,
#              'Category.Boots;Closure.Hook.and.Loop': 429,
#              'Category.Boots;Closure.Lace.up': 3613,
#              'Category.Boots;Closure.Monk.Strap': 0,
#              'Category.Boots;Closure.Pull.on': 4496,
#              'Category.Boots;Closure.Sling.Back': 0,
#              'Category.Boots;Closure.Slip.On': 16,
#              'Category.Boots;Closure.Snap': 45,
#              'Category.Boots;Closure.Spat.Strap': 19,
#              'Category.Boots;Closure.T.Strap': 0,
#              'Category.Boots;Closure.Toggle': 248,
#              'Category.Boots;Closure.Zipper': 4484,
#              'Category.Boots;Gender.Boys': 904,
#              'Category.Boots;Gender.Girls': 1840,
#              'Category.Boots;Gender.Men': 2800,
#              'Category.Boots;Gender.Women': 7701,
#              'Category.Boots;HeelHeight.High.heel': 665,
#              'Category.Boots;HeelHeight.Short.heel': 7162,
#              'Category.Boots;Material.Aluminum': 0,
#              'Category.Boots;Material.Corduroy': 2,
#              'Category.Boots;Material.Horse.Hair': 0,
#              'Category.Boots;Material.Plastic': 0,
#              'Category.Boots;Material.Rubber': 2187,
#              'Category.Boots;Material.Silk': 1,
#              'Category.Boots;Material.Snakeskin': 1,
#              'Category.Boots;Material.Stingray': 0,
#              'Category.Boots;Material.Suede': 2641,
#              'Category.Boots;Material.Wool': 70,
#              'Category.Boots;SubCategory.Ankle': 5855,
#              'Category.Boots;SubCategory.Athletic': 0,
#              'Category.Boots;SubCategory.Boat.Shoes': 0,
#              'Category.Boots;SubCategory.Boot': 0,
#              'Category.Boots;SubCategory.Clogs.and.Mules': 0,
#              'Category.Boots;SubCategory.Crib.Shoes': 0,
#              'Category.Boots;SubCategory.Firstwalker': 0,
#              'Category.Boots;SubCategory.Flats': 0,
#              'Category.Boots;SubCategory.Heel': 0,
#              'Category.Boots;SubCategory.Heels': 0,
#              'Category.Boots;SubCategory.Knee.High': 2202,
#              'Category.Boots;SubCategory.Loafers': 0,
#              'Category.Boots;SubCategory.Mid.Calf': 4724,
#              'Category.Boots;SubCategory.Over.the.Knee': 49,
#              'Category.Boots;SubCategory.Oxfords': 0,
#              'Category.Boots;SubCategory.Prewalker': 0,
#              'Category.Boots;SubCategory.Prewalker.Boots': 2,
#              'Category.Boots;SubCategory.Slipper.Flats': 0,
#              'Category.Boots;SubCategory.Slipper.Heels': 0,
#              'Category.Boots;SubCategory.Sneakers.and.Athletic.Shoes': 0,
#              'Category.Boots;ToeStyle.Algonquin': 11,
#              'Category.Boots;ToeStyle.Almond': 613,
#              'Category.Boots;ToeStyle.Apron Toe': 5,
#              'Category.Boots;ToeStyle.Bicycle Toe': 18,
#              'Category.Boots;ToeStyle.Bump Toe': 209,
#              'Category.Boots;ToeStyle.Capped Toe': 499,
#              'Category.Boots;ToeStyle.Center Seam': 199,
#              'Category.Boots;ToeStyle.Closed Toe': 7530,
#              'Category.Boots;ToeStyle.Medallion': 35,
#              'Category.Boots;ToeStyle.Moc Toe': 386,
#              'Category.Boots;ToeStyle.Open Toe': 21,
#              'Category.Boots;ToeStyle.Peep Toe': 23,
#              'Category.Boots;ToeStyle.Pointed Toe': 278,
#              'Category.Boots;ToeStyle.Round Toe': 8210,
#              'Category.Boots;ToeStyle.Snip Toe': 288,
#              'Category.Boots;ToeStyle.Snub Toe': 131,
#              'Category.Boots;ToeStyle.Square Toe': 327,
#              'Category.Boots;ToeStyle.Wide Toe Box': 6,
#              'Category.Boots;ToeStyle.Wingtip': 147,
#              'Category.Sandals;Category.Shoes': 0,
#              'Category.Sandals;Category.Slippers': 0,
#              'Category.Sandals;Closure.Adjustable': 0,
#              'Category.Sandals;Closure.Ankle.Strap': 792,
#              'Category.Sandals;Closure.Ankle.Wrap': 51,
#              'Category.Sandals;Closure.Belt': 0,
#              'Category.Sandals;Closure.Buckle': 1750,
#              'Category.Sandals;Closure.Bungee': 82,
#              'Category.Sandals;Closure.Button.Loop': 1,
#              'Category.Sandals;Closure.Elastic.Gore': 235,
#              'Category.Sandals;Closure.Hook.and.Loop': 908,
#              'Category.Sandals;Closure.Lace.up': 29,
#              'Category.Sandals;Closure.Monk.Strap': 6,
#              'Category.Sandals;Closure.Pull.on': 5,
#              'Category.Sandals;Closure.Sling.Back': 311,
#              'Category.Sandals;Closure.Slip.On': 2891,
#              'Category.Sandals;Closure.Snap': 10,
#              'Category.Sandals;Closure.Spat.Strap': 0,
#              'Category.Sandals;Closure.T.Strap': 22,
#              'Category.Sandals;Closure.Toggle': 33,
#              'Category.Sandals;Closure.Zipper': 153,
#              'Category.Sandals;Gender.Boys': 209,
#              'Category.Sandals;Gender.Girls': 547,
#              'Category.Sandals;Gender.Men': 722,
#              'Category.Sandals;Gender.Women': 4420,
#              'Category.Sandals;HeelHeight.High.heel': 558,
#              'Category.Sandals;HeelHeight.Short.heel': 2096,
#              'Category.Sandals;Material.Aluminum': 0,
#              'Category.Sandals;Material.Corduroy': 0,
#              'Category.Sandals;Material.Horse.Hair': 0,
#              'Category.Sandals;Material.Plastic': 0,
#              'Category.Sandals;Material.Rubber': 564,
#              'Category.Sandals;Material.Silk': 8,
#              'Category.Sandals;Material.Snakeskin': 2,
#              'Category.Sandals;Material.Stingray': 4,
#              'Category.Sandals;Material.Suede': 310,
#              'Category.Sandals;Material.Wool': 0,
#              'Category.Sandals;SubCategory.Ankle': 0,
#              'Category.Sandals;SubCategory.Athletic': 14,
#              'Category.Sandals;SubCategory.Boat.Shoes': 0,
#              'Category.Sandals;SubCategory.Boot': 0,
#              'Category.Sandals;SubCategory.Clogs.and.Mules': 0,
#              'Category.Sandals;SubCategory.Crib.Shoes': 0,
#              'Category.Sandals;SubCategory.Firstwalker': 0,
#              'Category.Sandals;SubCategory.Flats': 0,
#              'Category.Sandals;SubCategory.Heel': 126,
#              'Category.Sandals;SubCategory.Heels': 0,
#              'Category.Sandals;SubCategory.Knee.High': 0,
#              'Category.Sandals;SubCategory.Loafers': 0,
#              'Category.Sandals;SubCategory.Mid.Calf': 0,
#              'Category.Sandals;SubCategory.Over.the.Knee': 0,
#              'Category.Sandals;SubCategory.Oxfords': 0,
#              'Category.Sandals;SubCategory.Prewalker': 0,
#              'Category.Sandals;SubCategory.Prewalker.Boots': 0,
#              'Category.Sandals;SubCategory.Slipper.Flats': 0,
#              'Category.Sandals;SubCategory.Slipper.Heels': 0,
#              'Category.Sandals;SubCategory.Sneakers.and.Athletic.Shoes': 0,
#              'Category.Sandals;ToeStyle.Algonquin': 0,
#              'Category.Sandals;ToeStyle.Almond': 4,
#              'Category.Sandals;ToeStyle.Apron Toe': 0,
#              'Category.Sandals;ToeStyle.Bicycle Toe': 1,
#              'Category.Sandals;ToeStyle.Bump Toe': 87,
#              'Category.Sandals;ToeStyle.Capped Toe': 1,
#              'Category.Sandals;ToeStyle.Center Seam': 2,
#              'Category.Sandals;ToeStyle.Closed Toe': 158,
#              'Category.Sandals;ToeStyle.Medallion': 0,
#              'Category.Sandals;ToeStyle.Moc Toe': 1,
#              'Category.Sandals;ToeStyle.Open Toe': 4334,
#              'Category.Sandals;ToeStyle.Peep Toe': 268,
#              'Category.Sandals;ToeStyle.Pointed Toe': 2,
#              'Category.Sandals;ToeStyle.Round Toe': 258,
#              'Category.Sandals;ToeStyle.Snip Toe': 0,
#              'Category.Sandals;ToeStyle.Snub Toe': 2,
#              'Category.Sandals;ToeStyle.Square Toe': 1,
#              'Category.Sandals;ToeStyle.Wide Toe Box': 2,
#              'Category.Sandals;ToeStyle.Wingtip': 0,
#              'Category.Shoes;Category.Slippers': 0,
#              'Category.Shoes;Closure.Adjustable': 1,
#              'Category.Shoes;Closure.Ankle.Strap': 633,
#              'Category.Shoes;Closure.Ankle.Wrap': 51,
#              'Category.Shoes;Closure.Belt': 0,
#              'Category.Shoes;Closure.Buckle': 1528,
#              'Category.Shoes;Closure.Bungee': 296,
#              'Category.Shoes;Closure.Button.Loop': 28,
#              'Category.Shoes;Closure.Elastic.Gore': 995,
#              'Category.Shoes;Closure.Hook.and.Loop': 3390,
#              'Category.Shoes;Closure.Lace.up': 12564,
#              'Category.Shoes;Closure.Monk.Strap': 78,
#              'Category.Shoes;Closure.Pull.on': 15,
#              'Category.Shoes;Closure.Sling.Back': 171,
#              'Category.Shoes;Closure.Slip.On': 11812,
#              'Category.Shoes;Closure.Snap': 15,
#              'Category.Shoes;Closure.Spat.Strap': 1,
#              'Category.Shoes;Closure.T.Strap': 6,
#              'Category.Shoes;Closure.Toggle': 115,
#              'Category.Shoes;Closure.Zipper': 416,
#              'Category.Shoes;Gender.Boys': 3239,
#              'Category.Shoes;Gender.Girls': 3913,
#              'Category.Shoes;Gender.Men': 9478,
#              'Category.Shoes;Gender.Women': 15430,
#              'Category.Shoes;HeelHeight.High.heel': 2303,
#              'Category.Shoes;HeelHeight.Short.heel': 9904,
#              'Category.Shoes;Material.Aluminum': 14,
#              'Category.Shoes;Material.Corduroy': 21,
#              'Category.Shoes;Material.Horse.Hair': 4,
#              'Category.Shoes;Material.Plastic': 3,
#              'Category.Shoes;Material.Rubber': 4040,
#              'Category.Shoes;Material.Silk': 18,
#              'Category.Shoes;Material.Snakeskin': 10,
#              'Category.Shoes;Material.Stingray': 0,
#              'Category.Shoes;Material.Suede': 4999,
#              'Category.Shoes;Material.Wool': 145,
#              'Category.Shoes;SubCategory.Ankle': 0,
#              'Category.Shoes;SubCategory.Athletic': 0,
#              'Category.Shoes;SubCategory.Boat.Shoes': 629,
#              'Category.Shoes;SubCategory.Boot': 0,
#              'Category.Shoes;SubCategory.Clogs.and.Mules': 1427,
#              'Category.Shoes;SubCategory.Crib.Shoes': 23,
#              'Category.Shoes;SubCategory.Firstwalker': 369,
#              'Category.Shoes;SubCategory.Flats': 3994,
#              'Category.Shoes;SubCategory.Heel': 0,
#              'Category.Shoes;SubCategory.Heels': 5703,
#              'Category.Shoes;SubCategory.Knee.High': 0,
#              'Category.Shoes;SubCategory.Loafers': 2875,
#              'Category.Shoes;SubCategory.Mid.Calf': 0,
#              'Category.Shoes;SubCategory.Over.the.Knee': 0,
#              'Category.Shoes;SubCategory.Oxfords': 2044,
#              'Category.Shoes;SubCategory.Prewalker': 249,
#              'Category.Shoes;SubCategory.Prewalker.Boots': 0,
#              'Category.Shoes;SubCategory.Slipper.Flats': 0,
#              'Category.Shoes;SubCategory.Slipper.Heels': 0,
#              'Category.Shoes;SubCategory.Sneakers.and.Athletic.Shoes': 12856,
#              'Category.Shoes;ToeStyle.Algonquin': 71,
#              'Category.Shoes;ToeStyle.Almond': 885,
#              'Category.Shoes;ToeStyle.Apron Toe': 47,
#              'Category.Shoes;ToeStyle.Bicycle Toe': 265,
#              'Category.Shoes;ToeStyle.Bump Toe': 527,
#              'Category.Shoes;ToeStyle.Capped Toe': 1443,
#              'Category.Shoes;ToeStyle.Center Seam': 200,
#              'Category.Shoes;ToeStyle.Closed Toe': 11536,
#              'Category.Shoes;ToeStyle.Medallion': 120,
#              'Category.Shoes;ToeStyle.Moc Toe': 2279,
#              'Category.Shoes;ToeStyle.Open Toe': 891,
#              'Category.Shoes;ToeStyle.Peep Toe': 1151,
#              'Category.Shoes;ToeStyle.Pointed Toe': 997,
#              'Category.Shoes;ToeStyle.Round Toe': 12045,
#              'Category.Shoes;ToeStyle.Snip Toe': 153,
#              'Category.Shoes;ToeStyle.Snub Toe': 214,
#              'Category.Shoes;ToeStyle.Square Toe': 481,
#              'Category.Shoes;ToeStyle.Wide Toe Box': 175,
#              'Category.Shoes;ToeStyle.Wingtip': 565,
#              'Category.Slippers;Closure.Adjustable': 0,
#              'Category.Slippers;Closure.Ankle.Strap': 0,
#              'Category.Slippers;Closure.Ankle.Wrap': 0,
#              'Category.Slippers;Closure.Belt': 0,
#              'Category.Slippers;Closure.Buckle': 0,
#              'Category.Slippers;Closure.Bungee': 14,
#              'Category.Slippers;Closure.Button.Loop': 0,
#              'Category.Slippers;Closure.Elastic.Gore': 38,
#              'Category.Slippers;Closure.Hook.and.Loop': 126,
#              'Category.Slippers;Closure.Lace.up': 15,
#              'Category.Slippers;Closure.Monk.Strap': 0,
#              'Category.Slippers;Closure.Pull.on': 102,
#              'Category.Slippers;Closure.Sling.Back': 0,
#              'Category.Slippers;Closure.Slip.On': 1006,
#              'Category.Slippers;Closure.Snap': 0,
#              'Category.Slippers;Closure.Spat.Strap': 0,
#              'Category.Slippers;Closure.T.Strap': 0,
#              'Category.Slippers;Closure.Toggle': 14,
#              'Category.Slippers;Closure.Zipper': 10,
#              'Category.Slippers;Gender.Boys': 143,
#              'Category.Slippers;Gender.Girls': 250,
#              'Category.Slippers;Gender.Men': 337,
#              'Category.Slippers;Gender.Women': 637,
#              'Category.Slippers;HeelHeight.High.heel': 1,
#              'Category.Slippers;HeelHeight.Short.heel': 443,
#              'Category.Slippers;Material.Aluminum': 0,
#              'Category.Slippers;Material.Corduroy': 45,
#              'Category.Slippers;Material.Horse.Hair': 0,
#              'Category.Slippers;Material.Plastic': 0,
#              'Category.Slippers;Material.Rubber': 39,
#              'Category.Slippers;Material.Silk': 1,
#              'Category.Slippers;Material.Snakeskin': 0,
#              'Category.Slippers;Material.Stingray': 0,
#              'Category.Slippers;Material.Suede': 272,
#              'Category.Slippers;Material.Wool': 219,
#              'Category.Slippers;SubCategory.Ankle': 0,
#              'Category.Slippers;SubCategory.Athletic': 0,
#              'Category.Slippers;SubCategory.Boat.Shoes': 0,
#              'Category.Slippers;SubCategory.Boot': 14,
#              'Category.Slippers;SubCategory.Clogs.and.Mules': 0,
#              'Category.Slippers;SubCategory.Crib.Shoes': 0,
#              'Category.Slippers;SubCategory.Firstwalker': 0,
#              'Category.Slippers;SubCategory.Flats': 0,
#              'Category.Slippers;SubCategory.Heel': 0,
#              'Category.Slippers;SubCategory.Heels': 0,
#              'Category.Slippers;SubCategory.Knee.High': 0,
#              'Category.Slippers;SubCategory.Loafers': 0,
#              'Category.Slippers;SubCategory.Mid.Calf': 0,
#              'Category.Slippers;SubCategory.Over.the.Knee': 0,
#              'Category.Slippers;SubCategory.Oxfords': 0,
#              'Category.Slippers;SubCategory.Prewalker': 0,
#              'Category.Slippers;SubCategory.Prewalker.Boots': 0,
#              'Category.Slippers;SubCategory.Slipper.Flats': 1259,
#              'Category.Slippers;SubCategory.Slipper.Heels': 10,
#              'Category.Slippers;SubCategory.Sneakers.and.Athletic.Shoes': 0,
#              'Category.Slippers;ToeStyle.Algonquin': 7,
#              'Category.Slippers;ToeStyle.Almond': 0,
#              'Category.Slippers;ToeStyle.Apron Toe': 0,
#              'Category.Slippers;ToeStyle.Bicycle Toe': 4,
#              'Category.Slippers;ToeStyle.Bump Toe': 6,
#              'Category.Slippers;ToeStyle.Capped Toe': 1,
#              'Category.Slippers;ToeStyle.Center Seam': 74,
#              'Category.Slippers;ToeStyle.Closed Toe': 672,
#              'Category.Slippers;ToeStyle.Medallion': 0,
#              'Category.Slippers;ToeStyle.Moc Toe': 176,
#              'Category.Slippers;ToeStyle.Open Toe': 50,
#              'Category.Slippers;ToeStyle.Peep Toe': 0,
#              'Category.Slippers;ToeStyle.Pointed Toe': 0,
#              'Category.Slippers;ToeStyle.Round Toe': 814,
#              'Category.Slippers;ToeStyle.Snip Toe': 0,
#              'Category.Slippers;ToeStyle.Snub Toe': 12,
#              'Category.Slippers;ToeStyle.Square Toe': 1,
#              'Category.Slippers;ToeStyle.Wide Toe Box': 3,
#              'Category.Slippers;ToeStyle.Wingtip': 0,
#              'Closure.Adjustable;Closure.Ankle.Strap': 0,
#              'Closure.Adjustable;Closure.Ankle.Wrap': 0,
#              'Closure.Adjustable;Closure.Belt': 0,
#              'Closure.Adjustable;Closure.Buckle': 0,
#              'Closure.Adjustable;Closure.Bungee': 0,
#              'Closure.Adjustable;Closure.Button.Loop': 0,
#              'Closure.Adjustable;Closure.Elastic.Gore': 0,
#              'Closure.Adjustable;Closure.Hook.and.Loop': 0,
#              'Closure.Adjustable;Closure.Lace.up': 0,
#              'Closure.Adjustable;Closure.Monk.Strap': 0,
#              'Closure.Adjustable;Closure.Pull.on': 0,
#              'Closure.Adjustable;Closure.Sling.Back': 0,
#              'Closure.Adjustable;Closure.Slip.On': 0,
#              'Closure.Adjustable;Closure.Snap': 0,
#              'Closure.Adjustable;Closure.Spat.Strap': 0,
#              'Closure.Adjustable;Closure.T.Strap': 0,
#              'Closure.Adjustable;Closure.Toggle': 0,
#              'Closure.Adjustable;Closure.Zipper': 0,
#              'Closure.Adjustable;Gender.Boys': 0,
#              'Closure.Adjustable;Gender.Girls': 0,
#              'Closure.Adjustable;Gender.Men': 0,
#              'Closure.Adjustable;Gender.Women': 1,
#              'Closure.Adjustable;HeelHeight.High.heel': 0,
#              'Closure.Adjustable;HeelHeight.Short.heel': 0,
#              'Closure.Adjustable;Material.Aluminum': 1,
#              'Closure.Adjustable;Material.Corduroy': 0,
#              'Closure.Adjustable;Material.Horse.Hair': 0,
#              'Closure.Adjustable;Material.Plastic': 0,
#              'Closure.Adjustable;Material.Rubber': 0,
#              'Closure.Adjustable;Material.Silk': 0,
#              'Closure.Adjustable;Material.Snakeskin': 0,
#              'Closure.Adjustable;Material.Stingray': 0,
#              'Closure.Adjustable;Material.Suede': 0,
#              'Closure.Adjustable;Material.Wool': 0,
#              'Closure.Adjustable;SubCategory.Ankle': 0,
#              'Closure.Adjustable;SubCategory.Athletic': 0,
#              'Closure.Adjustable;SubCategory.Boat.Shoes': 0,
#              'Closure.Adjustable;SubCategory.Boot': 0,
#              'Closure.Adjustable;SubCategory.Clogs.and.Mules': 0,
#              'Closure.Adjustable;SubCategory.Crib.Shoes': 0,
#              'Closure.Adjustable;SubCategory.Firstwalker': 0,
#              'Closure.Adjustable;SubCategory.Flats': 0,
#              'Closure.Adjustable;SubCategory.Heel': 0,
#              'Closure.Adjustable;SubCategory.Heels': 0,
#              'Closure.Adjustable;SubCategory.Knee.High': 0,
#              'Closure.Adjustable;SubCategory.Loafers': 0,
#              'Closure.Adjustable;SubCategory.Mid.Calf': 0,
#              'Closure.Adjustable;SubCategory.Over.the.Knee': 0,
#              'Closure.Adjustable;SubCategory.Oxfords': 0,
#              'Closure.Adjustable;SubCategory.Prewalker': 0,
#              'Closure.Adjustable;SubCategory.Prewalker.Boots': 0,
#              'Closure.Adjustable;SubCategory.Slipper.Flats': 0,
#              'Closure.Adjustable;SubCategory.Slipper.Heels': 0,
#              'Closure.Adjustable;SubCategory.Sneakers.and.Athletic.Shoes': 1,
#              'Closure.Adjustable;ToeStyle.Algonquin': 0,
#              'Closure.Adjustable;ToeStyle.Almond': 0,
#              'Closure.Adjustable;ToeStyle.Apron Toe': 0,
#              'Closure.Adjustable;ToeStyle.Bicycle Toe': 0,
#              'Closure.Adjustable;ToeStyle.Bump Toe': 0,
#              'Closure.Adjustable;ToeStyle.Capped Toe': 0,
#              'Closure.Adjustable;ToeStyle.Center Seam': 0,
#              'Closure.Adjustable;ToeStyle.Closed Toe': 0,
#              'Closure.Adjustable;ToeStyle.Medallion': 0,
#              'Closure.Adjustable;ToeStyle.Moc Toe': 0,
#              'Closure.Adjustable;ToeStyle.Open Toe': 0,
#              'Closure.Adjustable;ToeStyle.Peep Toe': 0,
#              'Closure.Adjustable;ToeStyle.Pointed Toe': 0,
#              'Closure.Adjustable;ToeStyle.Round Toe': 0,
#              'Closure.Adjustable;ToeStyle.Snip Toe': 0,
#              'Closure.Adjustable;ToeStyle.Snub Toe': 0,
#              'Closure.Adjustable;ToeStyle.Square Toe': 0,
#              'Closure.Adjustable;ToeStyle.Wide Toe Box': 0,
#              'Closure.Adjustable;ToeStyle.Wingtip': 0,
#              'Closure.Ankle.Strap;Closure.Ankle.Wrap': 0,
#              'Closure.Ankle.Strap;Closure.Belt': 0,
#              'Closure.Ankle.Strap;Closure.Buckle': 0,
#              'Closure.Ankle.Strap;Closure.Bungee': 0,
#              'Closure.Ankle.Strap;Closure.Button.Loop': 0,
#              'Closure.Ankle.Strap;Closure.Elastic.Gore': 0,
#              'Closure.Ankle.Strap;Closure.Hook.and.Loop': 0,
#              'Closure.Ankle.Strap;Closure.Lace.up': 0,
#              'Closure.Ankle.Strap;Closure.Monk.Strap': 0,
#              'Closure.Ankle.Strap;Closure.Pull.on': 0,
#              'Closure.Ankle.Strap;Closure.Sling.Back': 0,
#              'Closure.Ankle.Strap;Closure.Slip.On': 0,
#              'Closure.Ankle.Strap;Closure.Snap': 0,
#              'Closure.Ankle.Strap;Closure.Spat.Strap': 0,
#              'Closure.Ankle.Strap;Closure.T.Strap': 0,
#              'Closure.Ankle.Strap;Closure.Toggle': 0,
#              'Closure.Ankle.Strap;Closure.Zipper': 0,
#              'Closure.Ankle.Strap;Gender.Boys': 19,
#              'Closure.Ankle.Strap;Gender.Girls': 96,
#              'Closure.Ankle.Strap;Gender.Men': 16,
#              'Closure.Ankle.Strap;Gender.Women': 1315,
#              'Closure.Ankle.Strap;HeelHeight.High.heel': 645,
#              'Closure.Ankle.Strap;HeelHeight.Short.heel': 314,
#              'Closure.Ankle.Strap;Material.Aluminum': 0,
#              'Closure.Ankle.Strap;Material.Corduroy': 0,
#              'Closure.Ankle.Strap;Material.Horse.Hair': 0,
#              'Closure.Ankle.Strap;Material.Plastic': 0,
#              'Closure.Ankle.Strap;Material.Rubber': 24,
#              'Closure.Ankle.Strap;Material.Silk': 3,
#              'Closure.Ankle.Strap;Material.Snakeskin': 4,
#              'Closure.Ankle.Strap;Material.Stingray': 0,
#              'Closure.Ankle.Strap;Material.Suede': 197,
#              'Closure.Ankle.Strap;Material.Wool': 0,
#              'Closure.Ankle.Strap;SubCategory.Ankle': 0,
#              'Closure.Ankle.Strap;SubCategory.Athletic': 0,
#              'Closure.Ankle.Strap;SubCategory.Boat.Shoes': 0,
#              'Closure.Ankle.Strap;SubCategory.Boot': 0,
#              'Closure.Ankle.Strap;SubCategory.Clogs.and.Mules': 4,
#              'Closure.Ankle.Strap;SubCategory.Crib.Shoes': 0,
#              'Closure.Ankle.Strap;SubCategory.Firstwalker': 3,
#              'Closure.Ankle.Strap;SubCategory.Flats': 60,
#              'Closure.Ankle.Strap;SubCategory.Heel': 18,
#              'Closure.Ankle.Strap;SubCategory.Heels': 561,
#              'Closure.Ankle.Strap;SubCategory.Knee.High': 0,
#              'Closure.Ankle.Strap;SubCategory.Loafers': 0,
#              'Closure.Ankle.Strap;SubCategory.Mid.Calf': 0,
#              'Closure.Ankle.Strap;SubCategory.Over.the.Knee': 0,
#              'Closure.Ankle.Strap;SubCategory.Oxfords': 0,
#              'Closure.Ankle.Strap;SubCategory.Prewalker': 2,
#              'Closure.Ankle.Strap;SubCategory.Prewalker.Boots': 0,
#              'Closure.Ankle.Strap;SubCategory.Slipper.Flats': 0,
#              'Closure.Ankle.Strap;SubCategory.Slipper.Heels': 0,
#              'Closure.Ankle.Strap;SubCategory.Sneakers.and.Athletic.Shoes': 3,
#              'Closure.Ankle.Strap;ToeStyle.Algonquin': 0,
#              'Closure.Ankle.Strap;ToeStyle.Almond': 31,
#              'Closure.Ankle.Strap;ToeStyle.Apron Toe': 0,
#              'Closure.Ankle.Strap;ToeStyle.Bicycle Toe': 0,
#              'Closure.Ankle.Strap;ToeStyle.Bump Toe': 4,
#              'Closure.Ankle.Strap;ToeStyle.Capped Toe': 8,
#              'Closure.Ankle.Strap;ToeStyle.Center Seam': 0,
#              'Closure.Ankle.Strap;ToeStyle.Closed Toe': 140,
#              'Closure.Ankle.Strap;ToeStyle.Medallion': 0,
#              'Closure.Ankle.Strap;ToeStyle.Moc Toe': 3,
#              'Closure.Ankle.Strap;ToeStyle.Open Toe': 972,
#              'Closure.Ankle.Strap;ToeStyle.Peep Toe': 202,
#              'Closure.Ankle.Strap;ToeStyle.Pointed Toe': 37,
#              'Closure.Ankle.Strap;ToeStyle.Round Toe': 150,
#              'Closure.Ankle.Strap;ToeStyle.Snip Toe': 3,
#              'Closure.Ankle.Strap;ToeStyle.Snub Toe': 13,
#              'Closure.Ankle.Strap;ToeStyle.Square Toe': 0,
#              'Closure.Ankle.Strap;ToeStyle.Wide Toe Box': 0,
#              'Closure.Ankle.Strap;ToeStyle.Wingtip': 0,
#              'Closure.Ankle.Wrap;Closure.Belt': 0,
#              'Closure.Ankle.Wrap;Closure.Buckle': 0,
#              'Closure.Ankle.Wrap;Closure.Bungee': 0,
#              'Closure.Ankle.Wrap;Closure.Button.Loop': 0,
#              'Closure.Ankle.Wrap;Closure.Elastic.Gore': 0,
#              'Closure.Ankle.Wrap;Closure.Hook.and.Loop': 0,
#              'Closure.Ankle.Wrap;Closure.Lace.up': 0,
#              'Closure.Ankle.Wrap;Closure.Monk.Strap': 0,
#              'Closure.Ankle.Wrap;Closure.Pull.on': 0,
#              'Closure.Ankle.Wrap;Closure.Sling.Back': 0,
#              'Closure.Ankle.Wrap;Closure.Slip.On': 0,
#              'Closure.Ankle.Wrap;Closure.Snap': 0,
#              'Closure.Ankle.Wrap;Closure.Spat.Strap': 0,
#              'Closure.Ankle.Wrap;Closure.T.Strap': 0,
#              'Closure.Ankle.Wrap;Closure.Toggle': 0,
#              'Closure.Ankle.Wrap;Closure.Zipper': 0,
#              'Closure.Ankle.Wrap;Gender.Boys': 0,
#              'Closure.Ankle.Wrap;Gender.Girls': 24,
#              'Closure.Ankle.Wrap;Gender.Men': 2,
#              'Closure.Ankle.Wrap;Gender.Women': 76,
#              'Closure.Ankle.Wrap;HeelHeight.High.heel': 27,
#              'Closure.Ankle.Wrap;HeelHeight.Short.heel': 21,
#              'Closure.Ankle.Wrap;Material.Aluminum': 0,
#              'Closure.Ankle.Wrap;Material.Corduroy': 0,
#              'Closure.Ankle.Wrap;Material.Horse.Hair': 0,
#              'Closure.Ankle.Wrap;Material.Plastic': 0,
#              'Closure.Ankle.Wrap;Material.Rubber': 1,
#              'Closure.Ankle.Wrap;Material.Silk': 0,
#              'Closure.Ankle.Wrap;Material.Snakeskin': 0,
#              'Closure.Ankle.Wrap;Material.Stingray': 0,
#              'Closure.Ankle.Wrap;Material.Suede': 8,
#              'Closure.Ankle.Wrap;Material.Wool': 0,
#              'Closure.Ankle.Wrap;SubCategory.Ankle': 0,
#              'Closure.Ankle.Wrap;SubCategory.Athletic': 0,
#              'Closure.Ankle.Wrap;SubCategory.Boat.Shoes': 0,
#              'Closure.Ankle.Wrap;SubCategory.Boot': 0,
#              'Closure.Ankle.Wrap;SubCategory.Clogs.and.Mules': 0,
#              'Closure.Ankle.Wrap;SubCategory.Crib.Shoes': 0,
#              'Closure.Ankle.Wrap;SubCategory.Firstwalker': 0,
#              'Closure.Ankle.Wrap;SubCategory.Flats': 15,
#              'Closure.Ankle.Wrap;SubCategory.Heel': 5,
#              'Closure.Ankle.Wrap;SubCategory.Heels': 30,
#              'Closure.Ankle.Wrap;SubCategory.Knee.High': 0,
#              'Closure.Ankle.Wrap;SubCategory.Loafers': 0,
#              'Closure.Ankle.Wrap;SubCategory.Mid.Calf': 0,
#              'Closure.Ankle.Wrap;SubCategory.Over.the.Knee': 0,
#              'Closure.Ankle.Wrap;SubCategory.Oxfords': 0,
#              'Closure.Ankle.Wrap;SubCategory.Prewalker': 6,
#              'Closure.Ankle.Wrap;SubCategory.Prewalker.Boots': 0,
#              'Closure.Ankle.Wrap;SubCategory.Slipper.Flats': 0,
#              'Closure.Ankle.Wrap;SubCategory.Slipper.Heels': 0,
#              'Closure.Ankle.Wrap;SubCategory.Sneakers.and.Athletic.Shoes': 0,
#              'Closure.Ankle.Wrap;ToeStyle.Algonquin': 0,
#              'Closure.Ankle.Wrap;ToeStyle.Almond': 7,
#              'Closure.Ankle.Wrap;ToeStyle.Apron Toe': 0,
#              'Closure.Ankle.Wrap;ToeStyle.Bicycle Toe': 0,
#              'Closure.Ankle.Wrap;ToeStyle.Bump Toe': 0,
#              'Closure.Ankle.Wrap;ToeStyle.Capped Toe': 0,
#              'Closure.Ankle.Wrap;ToeStyle.Center Seam': 0,
#              'Closure.Ankle.Wrap;ToeStyle.Closed Toe': 26,
#              'Closure.Ankle.Wrap;ToeStyle.Medallion': 0,
#              'Closure.Ankle.Wrap;ToeStyle.Moc Toe': 0,
#              'Closure.Ankle.Wrap;ToeStyle.Open Toe': 36,
#              'Closure.Ankle.Wrap;ToeStyle.Peep Toe': 9,
#              'Closure.Ankle.Wrap;ToeStyle.Pointed Toe': 2,
#              'Closure.Ankle.Wrap;ToeStyle.Round Toe': 32,
#              'Closure.Ankle.Wrap;ToeStyle.Snip Toe': 0,
#              'Closure.Ankle.Wrap;ToeStyle.Snub Toe': 1,
#              'Closure.Ankle.Wrap;ToeStyle.Square Toe': 3,
#              'Closure.Ankle.Wrap;ToeStyle.Wide Toe Box': 0,
#              'Closure.Ankle.Wrap;ToeStyle.Wingtip': 0,
#              'Closure.Belt;Closure.Buckle': 0,
#              'Closure.Belt;Closure.Bungee': 0,
#              'Closure.Belt;Closure.Button.Loop': 0,
#              'Closure.Belt;Closure.Elastic.Gore': 0,
#              'Closure.Belt;Closure.Hook.and.Loop': 0,
#              'Closure.Belt;Closure.Lace.up': 0,
#              'Closure.Belt;Closure.Monk.Strap': 0,
#              'Closure.Belt;Closure.Pull.on': 0,
#              'Closure.Belt;Closure.Sling.Back': 0,
#              'Closure.Belt;Closure.Slip.On': 0,
#              'Closure.Belt;Closure.Snap': 0,
#              'Closure.Belt;Closure.Spat.Strap': 0,
#              'Closure.Belt;Closure.T.Strap': 0,
#              'Closure.Belt;Closure.Toggle': 0,
#              'Closure.Belt;Closure.Zipper': 0,
#              'Closure.Belt;Gender.Boys': 1,
#              'Closure.Belt;Gender.Girls': 2,
#              'Closure.Belt;Gender.Men': 2,
#              'Closure.Belt;Gender.Women': 3,
#              'Closure.Belt;HeelHeight.High.heel': 0,
#              'Closure.Belt;HeelHeight.Short.heel': 7,
#              'Closure.Belt;Material.Aluminum': 0,
#              'Closure.Belt;Material.Corduroy': 0,
#              'Closure.Belt;Material.Horse.Hair': 0,
#              'Closure.Belt;Material.Plastic': 0,
#              'Closure.Belt;Material.Rubber': 1,
#              'Closure.Belt;Material.Silk': 0,
#              'Closure.Belt;Material.Snakeskin': 0,
#              'Closure.Belt;Material.Stingray': 0,
#              'Closure.Belt;Material.Suede': 1,
#              'Closure.Belt;Material.Wool': 0,
#              'Closure.Belt;SubCategory.Ankle': 1,
#              'Closure.Belt;SubCategory.Athletic': 0,
#              'Closure.Belt;SubCategory.Boat.Shoes': 0,
#              'Closure.Belt;SubCategory.Boot': 0,
#              'Closure.Belt;SubCategory.Clogs.and.Mules': 0,
#              'Closure.Belt;SubCategory.Crib.Shoes': 0,
#              'Closure.Belt;SubCategory.Firstwalker': 0,
#              'Closure.Belt;SubCategory.Flats': 0,
#              'Closure.Belt;SubCategory.Heel': 0,
#              'Closure.Belt;SubCategory.Heels': 0,
#              'Closure.Belt;SubCategory.Knee.High': 1,
#              'Closure.Belt;SubCategory.Loafers': 0,
#              'Closure.Belt;SubCategory.Mid.Calf': 6,
#              'Closure.Belt;SubCategory.Over.the.Knee': 0,
#              'Closure.Belt;SubCategory.Oxfords': 0,
#              'Closure.Belt;SubCategory.Prewalker': 0,
#              'Closure.Belt;SubCategory.Prewalker.Boots': 0,
#              'Closure.Belt;SubCategory.Slipper.Flats': 0,
#              'Closure.Belt;SubCategory.Slipper.Heels': 0,
#              'Closure.Belt;SubCategory.Sneakers.and.Athletic.Shoes': 0,
#              'Closure.Belt;ToeStyle.Algonquin': 0,
#              'Closure.Belt;ToeStyle.Almond': 0,
#              'Closure.Belt;ToeStyle.Apron Toe': 0,
#              'Closure.Belt;ToeStyle.Bicycle Toe': 0,
#              'Closure.Belt;ToeStyle.Bump Toe': 0,
#              'Closure.Belt;ToeStyle.Capped Toe': 2,
#              'Closure.Belt;ToeStyle.Center Seam': 0,
#              'Closure.Belt;ToeStyle.Closed Toe': 2,
#              'Closure.Belt;ToeStyle.Medallion': 0,
#              'Closure.Belt;ToeStyle.Moc Toe': 0,
#              'Closure.Belt;ToeStyle.Open Toe': 0,
#              'Closure.Belt;ToeStyle.Peep Toe': 0,
#              'Closure.Belt;ToeStyle.Pointed Toe': 0,
#              'Closure.Belt;ToeStyle.Round Toe': 3,
#              'Closure.Belt;ToeStyle.Snip Toe': 0,
#              'Closure.Belt;ToeStyle.Snub Toe': 0,
#              'Closure.Belt;ToeStyle.Square Toe': 0,
#              'Closure.Belt;ToeStyle.Wide Toe Box': 0,
#              'Closure.Belt;ToeStyle.Wingtip': 0,
#              'Closure.Buckle;Closure.Bungee': 0,
#              'Closure.Buckle;Closure.Button.Loop': 0,
#              'Closure.Buckle;Closure.Elastic.Gore': 0,
#              'Closure.Buckle;Closure.Hook.and.Loop': 0,
#              'Closure.Buckle;Closure.Lace.up': 0,
#              'Closure.Buckle;Closure.Monk.Strap': 0,
#              'Closure.Buckle;Closure.Pull.on': 0,
#              'Closure.Buckle;Closure.Sling.Back': 0,
#              'Closure.Buckle;Closure.Slip.On': 0,
#              'Closure.Buckle;Closure.Snap': 0,
#              'Closure.Buckle;Closure.Spat.Strap': 0,
#              'Closure.Buckle;Closure.T.Strap': 0,
#              'Closure.Buckle;Closure.Toggle': 0,
#              'Closure.Buckle;Closure.Zipper': 0,
#              'Closure.Buckle;Gender.Boys': 79,
#              'Closure.Buckle;Gender.Girls': 445,
#              'Closure.Buckle;Gender.Men': 169,
#              'Closure.Buckle;Gender.Women': 3059,
#              'Closure.Buckle;HeelHeight.High.heel': 1016,
#              'Closure.Buckle;HeelHeight.Short.heel': 1089,
#              'Closure.Buckle;Material.Aluminum': 1,
#              'Closure.Buckle;Material.Corduroy': 0,
#              'Closure.Buckle;Material.Horse.Hair': 0,
#              'Closure.Buckle;Material.Plastic': 0,
#              'Closure.Buckle;Material.Rubber': 174,
#              'Closure.Buckle;Material.Silk': 3,
#              'Closure.Buckle;Material.Snakeskin': 4,
#              'Closure.Buckle;Material.Stingray': 0,
#              'Closure.Buckle;Material.Suede': 439,
#              'Closure.Buckle;Material.Wool': 13,
#              'Closure.Buckle;SubCategory.Ankle': 121,
#              'Closure.Buckle;SubCategory.Athletic': 0,
#              'Closure.Buckle;SubCategory.Boat.Shoes': 0,
#              'Closure.Buckle;SubCategory.Boot': 0,
#              'Closure.Buckle;SubCategory.Clogs.and.Mules': 108,
#              'Closure.Buckle;SubCategory.Crib.Shoes': 0,
#              'Closure.Buckle;SubCategory.Firstwalker': 5,
#              'Closure.Buckle;SubCategory.Flats': 204,
#              'Closure.Buckle;SubCategory.Heel': 45,
#              'Closure.Buckle;SubCategory.Heels': 1132,
#              'Closure.Buckle;SubCategory.Knee.High': 50,
#              'Closure.Buckle;SubCategory.Loafers': 21,
#              'Closure.Buckle;SubCategory.Mid.Calf': 198,
#              'Closure.Buckle;SubCategory.Over.the.Knee': 1,
#              'Closure.Buckle;SubCategory.Oxfords': 12,
#              'Closure.Buckle;SubCategory.Prewalker': 0,
#              'Closure.Buckle;SubCategory.Prewalker.Boots': 0,
#              'Closure.Buckle;SubCategory.Slipper.Flats': 0,
#              'Closure.Buckle;SubCategory.Slipper.Heels': 0,
#              'Closure.Buckle;SubCategory.Sneakers.and.Athletic.Shoes': 46,
#              'Closure.Buckle;ToeStyle.Algonquin': 1,
#              'Closure.Buckle;ToeStyle.Almond': 83,
#              'Closure.Buckle;ToeStyle.Apron Toe': 1,
#              'Closure.Buckle;ToeStyle.Bicycle Toe': 1,
#              'Closure.Buckle;ToeStyle.Bump Toe': 7,
#              'Closure.Buckle;ToeStyle.Capped Toe': 77,
#              'Closure.Buckle;ToeStyle.Center Seam': 12,
#              'Closure.Buckle;ToeStyle.Closed Toe': 709,
#              'Closure.Buckle;ToeStyle.Medallion': 3,
#              'Closure.Buckle;ToeStyle.Moc Toe': 11,
#              'Closure.Buckle;ToeStyle.Open Toe': 1792,
#              'Closure.Buckle;ToeStyle.Peep Toe': 416,
#              'Closure.Buckle;ToeStyle.Pointed Toe': 87,
#              'Closure.Buckle;ToeStyle.Round Toe': 934,
#              'Closure.Buckle;ToeStyle.Snip Toe': 8,
#              'Closure.Buckle;ToeStyle.Snub Toe': 16,
#              'Closure.Buckle;ToeStyle.Square Toe': 10,
#              'Closure.Buckle;ToeStyle.Wide Toe Box': 2,
#              'Closure.Buckle;ToeStyle.Wingtip': 7,
#              'Closure.Bungee;Closure.Button.Loop': 0,
#              'Closure.Bungee;Closure.Elastic.Gore': 0,
#              'Closure.Bungee;Closure.Hook.and.Loop': 0,
#              'Closure.Bungee;Closure.Lace.up': 0,
#              'Closure.Bungee;Closure.Monk.Strap': 0,
#              'Closure.Bungee;Closure.Pull.on': 0,
#              'Closure.Bungee;Closure.Sling.Back': 0,
#              'Closure.Bungee;Closure.Slip.On': 0,
#              'Closure.Bungee;Closure.Snap': 0,
#              'Closure.Bungee;Closure.Spat.Strap': 0,
#              'Closure.Bungee;Closure.T.Strap': 0,
#              'Closure.Bungee;Closure.Toggle': 0,
#              'Closure.Bungee;Closure.Zipper': 0,
#              'Closure.Bungee;Gender.Boys': 209,
#              'Closure.Bungee;Gender.Girls': 191,
#              'Closure.Bungee;Gender.Men': 114,
#              'Closure.Bungee;Gender.Women': 181,
#              'Closure.Bungee;HeelHeight.High.heel': 7,
#              'Closure.Bungee;HeelHeight.Short.heel': 222,
#              'Closure.Bungee;Material.Aluminum': 0,
#              'Closure.Bungee;Material.Corduroy': 0,
#              'Closure.Bungee;Material.Horse.Hair': 0,
#              'Closure.Bungee;Material.Plastic': 0,
#              'Closure.Bungee;Material.Rubber': 138,
#              'Closure.Bungee;Material.Silk': 0,
#              'Closure.Bungee;Material.Snakeskin': 0,
#              'Closure.Bungee;Material.Stingray': 0,
#              'Closure.Bungee;Material.Suede': 78,
#              'Closure.Bungee;Material.Wool': 7,
#              'Closure.Bungee;SubCategory.Ankle': 40,
#              'Closure.Bungee;SubCategory.Athletic': 2,
#              'Closure.Bungee;SubCategory.Boat.Shoes': 0,
#              'Closure.Bungee;SubCategory.Boot': 3,
#              'Closure.Bungee;SubCategory.Clogs.and.Mules': 4,
#              'Closure.Bungee;SubCategory.Crib.Shoes': 0,
#              'Closure.Bungee;SubCategory.Firstwalker': 0,
#              'Closure.Bungee;SubCategory.Flats': 2,
#              'Closure.Bungee;SubCategory.Heel': 0,
#              'Closure.Bungee;SubCategory.Heels': 0,
#              'Closure.Bungee;SubCategory.Knee.High': 26,
#              'Closure.Bungee;SubCategory.Loafers': 0,
#              'Closure.Bungee;SubCategory.Mid.Calf': 182,
#              'Closure.Bungee;SubCategory.Over.the.Knee': 0,
#              'Closure.Bungee;SubCategory.Oxfords': 0,
#              'Closure.Bungee;SubCategory.Prewalker': 0,
#              'Closure.Bungee;SubCategory.Prewalker.Boots': 0,
#              'Closure.Bungee;SubCategory.Slipper.Flats': 11,
#              'Closure.Bungee;SubCategory.Slipper.Heels': 0,
#              'Closure.Bungee;SubCategory.Sneakers.and.Athletic.Shoes': 290,
#              'Closure.Bungee;ToeStyle.Algonquin': 0,
#              'Closure.Bungee;ToeStyle.Almond': 0,
#              'Closure.Bungee;ToeStyle.Apron Toe': 0,
#              'Closure.Bungee;ToeStyle.Bicycle Toe': 0,
#              'Closure.Bungee;ToeStyle.Bump Toe': 82,
#              'Closure.Bungee;ToeStyle.Capped Toe': 10,
#              'Closure.Bungee;ToeStyle.Center Seam': 3,
#              'Closure.Bungee;ToeStyle.Closed Toe': 167,
#              'Closure.Bungee;ToeStyle.Medallion': 0,
#              'Closure.Bungee;ToeStyle.Moc Toe': 2,
#              'Closure.Bungee;ToeStyle.Open Toe': 8,
#              'Closure.Bungee;ToeStyle.Peep Toe': 6,
#              'Closure.Bungee;ToeStyle.Pointed Toe': 0,
#              'Closure.Bungee;ToeStyle.Round Toe': 214,
#              'Closure.Bungee;ToeStyle.Snip Toe': 3,
#              'Closure.Bungee;ToeStyle.Snub Toe': 1,
#              'Closure.Bungee;ToeStyle.Square Toe': 0,
#              'Closure.Bungee;ToeStyle.Wide Toe Box': 4,
#              'Closure.Bungee;ToeStyle.Wingtip': 0,
#              'Closure.Button.Loop;Closure.Elastic.Gore': 0,
#              'Closure.Button.Loop;Closure.Hook.and.Loop': 0,
#              'Closure.Button.Loop;Closure.Lace.up': 0,
#              'Closure.Button.Loop;Closure.Monk.Strap': 0,
#              'Closure.Button.Loop;Closure.Pull.on': 0,
#              'Closure.Button.Loop;Closure.Sling.Back': 0,
#              'Closure.Button.Loop;Closure.Slip.On': 0,
#              'Closure.Button.Loop;Closure.Snap': 0,
#              'Closure.Button.Loop;Closure.Spat.Strap': 0,
#              'Closure.Button.Loop;Closure.T.Strap': 0,
#              'Closure.Button.Loop;Closure.Toggle': 0,
#              'Closure.Button.Loop;Closure.Zipper': 0,
#              'Closure.Button.Loop;Gender.Boys': 0,
#              'Closure.Button.Loop;Gender.Girls': 46,
#              'Closure.Button.Loop;Gender.Men': 1,
#              'Closure.Button.Loop;Gender.Women': 64,
#              'Closure.Button.Loop;HeelHeight.High.heel': 4,
#              'Closure.Button.Loop;HeelHeight.Short.heel': 59,
#              'Closure.Button.Loop;Material.Aluminum': 0,
#              'Closure.Button.Loop;Material.Corduroy': 2,
#              'Closure.Button.Loop;Material.Horse.Hair': 0,
#              'Closure.Button.Loop;Material.Plastic': 0,
#              'Closure.Button.Loop;Material.Rubber': 0,
#              'Closure.Button.Loop;Material.Silk': 0,
#              'Closure.Button.Loop;Material.Snakeskin': 0,
#              'Closure.Button.Loop;Material.Stingray': 0,
#              'Closure.Button.Loop;Material.Suede': 38,
#              'Closure.Button.Loop;Material.Wool': 11,
#              'Closure.Button.Loop;SubCategory.Ankle': 47,
#              'Closure.Button.Loop;SubCategory.Athletic': 0,
#              'Closure.Button.Loop;SubCategory.Boat.Shoes': 0,
#              'Closure.Button.Loop;SubCategory.Boot': 0,
#              'Closure.Button.Loop;SubCategory.Clogs.and.Mules': 1,
#              'Closure.Button.Loop;SubCategory.Crib.Shoes': 0,
#              'Closure.Button.Loop;SubCategory.Firstwalker': 0,
#              'Closure.Button.Loop;SubCategory.Flats': 1,
#              'Closure.Button.Loop;SubCategory.Heel': 0,
#              'Closure.Button.Loop;SubCategory.Heels': 14,
#              'Closure.Button.Loop;SubCategory.Knee.High': 14,
#              'Closure.Button.Loop;SubCategory.Loafers': 7,
#              'Closure.Button.Loop;SubCategory.Mid.Calf': 21,
#              'Closure.Button.Loop;SubCategory.Over.the.Knee': 0,
#              'Closure.Button.Loop;SubCategory.Oxfords': 0,
#              'Closure.Button.Loop;SubCategory.Prewalker': 2,
#              'Closure.Button.Loop;SubCategory.Prewalker.Boots': 0,
#              'Closure.Button.Loop;SubCategory.Slipper.Flats': 0,
#              'Closure.Button.Loop;SubCategory.Slipper.Heels': 0,
#              'Closure.Button.Loop;SubCategory.Sneakers.and.Athletic.Shoes': 3,
#              'Closure.Button.Loop;ToeStyle.Algonquin': 0,
#              'Closure.Button.Loop;ToeStyle.Almond': 1,
#              'Closure.Button.Loop;ToeStyle.Apron Toe': 0,
#              'Closure.Button.Loop;ToeStyle.Bicycle Toe': 0,
#              'Closure.Button.Loop;ToeStyle.Bump Toe': 0,
#              'Closure.Button.Loop;ToeStyle.Capped Toe': 5,
#              'Closure.Button.Loop;ToeStyle.Center Seam': 5,
#              'Closure.Button.Loop;ToeStyle.Closed Toe': 68,
#              'Closure.Button.Loop;ToeStyle.Medallion': 0,
#              'Closure.Button.Loop;ToeStyle.Moc Toe': 0,
#              'Closure.Button.Loop;ToeStyle.Open Toe': 1,
#              'Closure.Button.Loop;ToeStyle.Peep Toe': 0,
#              'Closure.Button.Loop;ToeStyle.Pointed Toe': 3,
#              'Closure.Button.Loop;ToeStyle.Round Toe': 82,
#              'Closure.Button.Loop;ToeStyle.Snip Toe': 0,
#              'Closure.Button.Loop;ToeStyle.Snub Toe': 0,
#              'Closure.Button.Loop;ToeStyle.Square Toe': 5,
#              'Closure.Button.Loop;ToeStyle.Wide Toe Box': 0,
#              'Closure.Button.Loop;ToeStyle.Wingtip': 0,
#              'Closure.Elastic.Gore;Closure.Hook.and.Loop': 0,
#              'Closure.Elastic.Gore;Closure.Lace.up': 0,
#              'Closure.Elastic.Gore;Closure.Monk.Strap': 0,
#              'Closure.Elastic.Gore;Closure.Pull.on': 0,
#              'Closure.Elastic.Gore;Closure.Sling.Back': 0,
#              'Closure.Elastic.Gore;Closure.Slip.On': 0,
#              'Closure.Elastic.Gore;Closure.Snap': 0,
#              'Closure.Elastic.Gore;Closure.Spat.Strap': 0,
#              'Closure.Elastic.Gore;Closure.T.Strap': 0,
#              'Closure.Elastic.Gore;Closure.Toggle': 0,
#              'Closure.Elastic.Gore;Closure.Zipper': 0,
#              'Closure.Elastic.Gore;Gender.Boys': 97,
#              'Closure.Elastic.Gore;Gender.Girls': 133,
#              'Closure.Elastic.Gore;Gender.Men': 501,
#              'Closure.Elastic.Gore;Gender.Women': 1072,
#              'Closure.Elastic.Gore;HeelHeight.High.heel': 94,
#              'Closure.Elastic.Gore;HeelHeight.Short.heel': 719,
#              'Closure.Elastic.Gore;Material.Aluminum': 0,
#              'Closure.Elastic.Gore;Material.Corduroy': 11,
#              'Closure.Elastic.Gore;Material.Horse.Hair': 0,
#              'Closure.Elastic.Gore;Material.Plastic': 0,
#              'Closure.Elastic.Gore;Material.Rubber': 144,
#              'Closure.Elastic.Gore;Material.Silk': 0,
#              'Closure.Elastic.Gore;Material.Snakeskin': 0,
#              'Closure.Elastic.Gore;Material.Stingray': 0,
#              'Closure.Elastic.Gore;Material.Suede': 214,
#              'Closure.Elastic.Gore;Material.Wool': 13,
#              'Closure.Elastic.Gore;SubCategory.Ankle': 336,
#              'Closure.Elastic.Gore;SubCategory.Athletic': 0,
#              'Closure.Elastic.Gore;SubCategory.Boat.Shoes': 8,
#              'Closure.Elastic.Gore;SubCategory.Boot': 0,
#              'Closure.Elastic.Gore;SubCategory.Clogs.and.Mules': 83,
#              'Closure.Elastic.Gore;SubCategory.Crib.Shoes': 0,
#              'Closure.Elastic.Gore;SubCategory.Firstwalker': 4,
#              'Closure.Elastic.Gore;SubCategory.Flats': 134,
#              'Closure.Elastic.Gore;SubCategory.Heel': 28,
#              'Closure.Elastic.Gore;SubCategory.Heels': 181,
#              'Closure.Elastic.Gore;SubCategory.Knee.High': 82,
#              'Closure.Elastic.Gore;SubCategory.Loafers': 368,
#              'Closure.Elastic.Gore;SubCategory.Mid.Calf': 53,
#              'Closure.Elastic.Gore;SubCategory.Over.the.Knee': 2,
#              'Closure.Elastic.Gore;SubCategory.Oxfords': 8,
#              'Closure.Elastic.Gore;SubCategory.Prewalker': 0,
#              'Closure.Elastic.Gore;SubCategory.Prewalker.Boots': 0,
#              'Closure.Elastic.Gore;SubCategory.Slipper.Flats': 38,
#              'Closure.Elastic.Gore;SubCategory.Slipper.Heels': 0,
#              'Closure.Elastic.Gore;SubCategory.Sneakers.and.Athletic.Shoes': 209,
#              'Closure.Elastic.Gore;ToeStyle.Algonquin': 3,
#              'Closure.Elastic.Gore;ToeStyle.Almond': 47,
#              'Closure.Elastic.Gore;ToeStyle.Apron Toe': 6,
#              'Closure.Elastic.Gore;ToeStyle.Bicycle Toe': 65,
#              'Closure.Elastic.Gore;ToeStyle.Bump Toe': 42,
#              'Closure.Elastic.Gore;ToeStyle.Capped Toe': 22,
#              'Closure.Elastic.Gore;ToeStyle.Center Seam': 52,
#              'Closure.Elastic.Gore;ToeStyle.Closed Toe': 784,
#              'Closure.Elastic.Gore;ToeStyle.Medallion': 7,
#              'Closure.Elastic.Gore;ToeStyle.Moc Toe': 91,
#              'Closure.Elastic.Gore;ToeStyle.Open Toe': 216,
#              'Closure.Elastic.Gore;ToeStyle.Peep Toe': 58,
#              'Closure.Elastic.Gore;ToeStyle.Pointed Toe': 17,
#              'Closure.Elastic.Gore;ToeStyle.Round Toe': 1007,
#              'Closure.Elastic.Gore;ToeStyle.Snip Toe': 13,
#              'Closure.Elastic.Gore;ToeStyle.Snub Toe': 19,
#              'Closure.Elastic.Gore;ToeStyle.Square Toe': 43,
#              'Closure.Elastic.Gore;ToeStyle.Wide Toe Box': 5,
#              'Closure.Elastic.Gore;ToeStyle.Wingtip': 16,
#              'Closure.Hook.and.Loop;Closure.Lace.up': 0,
#              'Closure.Hook.and.Loop;Closure.Monk.Strap': 0,
#              'Closure.Hook.and.Loop;Closure.Pull.on': 0,
#              'Closure.Hook.and.Loop;Closure.Sling.Back': 0,
#              'Closure.Hook.and.Loop;Closure.Slip.On': 0,
#              'Closure.Hook.and.Loop;Closure.Snap': 0,
#              'Closure.Hook.and.Loop;Closure.Spat.Strap': 0,
#              'Closure.Hook.and.Loop;Closure.T.Strap': 0,
#              'Closure.Hook.and.Loop;Closure.Toggle': 0,
#              'Closure.Hook.and.Loop;Closure.Zipper': 0,
#              'Closure.Hook.and.Loop;Gender.Boys': 1391,
#              'Closure.Hook.and.Loop;Gender.Girls': 1850,
#              'Closure.Hook.and.Loop;Gender.Men': 403,
#              'Closure.Hook.and.Loop;Gender.Women': 1418,
#              'Closure.Hook.and.Loop;HeelHeight.High.heel': 35,
#              'Closure.Hook.and.Loop;HeelHeight.Short.heel': 1763,
#              'Closure.Hook.and.Loop;Material.Aluminum': 0,
#              'Closure.Hook.and.Loop;Material.Corduroy': 7,
#              'Closure.Hook.and.Loop;Material.Horse.Hair': 0,
#              'Closure.Hook.and.Loop;Material.Plastic': 0,
#              'Closure.Hook.and.Loop;Material.Rubber': 299,
#              'Closure.Hook.and.Loop;Material.Silk': 0,
#              'Closure.Hook.and.Loop;Material.Snakeskin': 0,
#              'Closure.Hook.and.Loop;Material.Stingray': 0,
#              'Closure.Hook.and.Loop;Material.Suede': 622,
#              'Closure.Hook.and.Loop;Material.Wool': 30,
#              'Closure.Hook.and.Loop;SubCategory.Ankle': 275,
#              'Closure.Hook.and.Loop;SubCategory.Athletic': 9,
#              'Closure.Hook.and.Loop;SubCategory.Boat.Shoes': 13,
#              'Closure.Hook.and.Loop;SubCategory.Boot': 3,
#              'Closure.Hook.and.Loop;SubCategory.Clogs.and.Mules': 124,
#              'Closure.Hook.and.Loop;SubCategory.Crib.Shoes': 14,
#              'Closure.Hook.and.Loop;SubCategory.Firstwalker': 319,
#              'Closure.Hook.and.Loop;SubCategory.Flats': 880,
#              'Closure.Hook.and.Loop;SubCategory.Heel': 25,
#              'Closure.Hook.and.Loop;SubCategory.Heels': 210,
#              'Closure.Hook.and.Loop;SubCategory.Knee.High': 4,
#              'Closure.Hook.and.Loop;SubCategory.Loafers': 94,
#              'Closure.Hook.and.Loop;SubCategory.Mid.Calf': 149,
#              'Closure.Hook.and.Loop;SubCategory.Over.the.Knee': 0,
#              'Closure.Hook.and.Loop;SubCategory.Oxfords': 41,
#              'Closure.Hook.and.Loop;SubCategory.Prewalker': 147,
#              'Closure.Hook.and.Loop;SubCategory.Prewalker.Boots': 1,
#              'Closure.Hook.and.Loop;SubCategory.Slipper.Flats': 123,
#              'Closure.Hook.and.Loop;SubCategory.Slipper.Heels': 0,
#              'Closure.Hook.and.Loop;SubCategory.Sneakers.and.Athletic.Shoes': 1548,
#              'Closure.Hook.and.Loop;ToeStyle.Algonquin': 0,
#              'Closure.Hook.and.Loop;ToeStyle.Almond': 25,
#              'Closure.Hook.and.Loop;ToeStyle.Apron Toe': 0,
#              'Closure.Hook.and.Loop;ToeStyle.Bicycle Toe': 14,
#              'Closure.Hook.and.Loop;ToeStyle.Bump Toe': 423,
#              'Closure.Hook.and.Loop;ToeStyle.Capped Toe': 159,
#              'Closure.Hook.and.Loop;ToeStyle.Center Seam': 34,
#              'Closure.Hook.and.Loop;ToeStyle.Closed Toe': 2033,
#              'Closure.Hook.and.Loop;ToeStyle.Medallion': 3,
#              'Closure.Hook.and.Loop;ToeStyle.Moc Toe': 95,
#              'Closure.Hook.and.Loop;ToeStyle.Open Toe': 663,
#              'Closure.Hook.and.Loop;ToeStyle.Peep Toe': 11,
#              'Closure.Hook.and.Loop;ToeStyle.Pointed Toe': 1,
#              'Closure.Hook.and.Loop;ToeStyle.Round Toe': 2372,
#              'Closure.Hook.and.Loop;ToeStyle.Snip Toe': 11,
#              'Closure.Hook.and.Loop;ToeStyle.Snub Toe': 2,
#              'Closure.Hook.and.Loop;ToeStyle.Square Toe': 7,
#              'Closure.Hook.and.Loop;ToeStyle.Wide Toe Box': 61,
#              'Closure.Hook.and.Loop;ToeStyle.Wingtip': 19,
#              'Closure.Lace.up;Closure.Monk.Strap': 0,
#              'Closure.Lace.up;Closure.Pull.on': 0,
#              'Closure.Lace.up;Closure.Sling.Back': 0,
#              'Closure.Lace.up;Closure.Slip.On': 0,
#              'Closure.Lace.up;Closure.Snap': 0,
#              'Closure.Lace.up;Closure.Spat.Strap': 0,
#              'Closure.Lace.up;Closure.T.Strap': 0,
#              'Closure.Lace.up;Closure.Toggle': 0,
#              'Closure.Lace.up;Closure.Zipper': 0,
#              'Closure.Lace.up;Gender.Boys': 2094,
#              'Closure.Lace.up;Gender.Girls': 1594,
#              'Closure.Lace.up;Gender.Men': 8658,
#              'Closure.Lace.up;Gender.Women': 5405,
#              'Closure.Lace.up;HeelHeight.High.heel': 140,
#              'Closure.Lace.up;HeelHeight.Short.heel': 5842,
#              'Closure.Lace.up;Material.Aluminum': 0,
#              'Closure.Lace.up;Material.Corduroy': 9,
#              'Closure.Lace.up;Material.Horse.Hair': 0,
#              'Closure.Lace.up;Material.Plastic': 0,
#              'Closure.Lace.up;Material.Rubber': 3819,
#              'Closure.Lace.up;Material.Silk': 0,
#              'Closure.Lace.up;Material.Snakeskin': 0,
#              'Closure.Lace.up;Material.Stingray': 0,
#              'Closure.Lace.up;Material.Suede': 3024,
#              'Closure.Lace.up;Material.Wool': 78,
#              'Closure.Lace.up;SubCategory.Ankle': 2720,
#              'Closure.Lace.up;SubCategory.Athletic': 0,
#              'Closure.Lace.up;SubCategory.Boat.Shoes': 343,
#              'Closure.Lace.up;SubCategory.Boot': 0,
#              'Closure.Lace.up;SubCategory.Clogs.and.Mules': 0,
#              'Closure.Lace.up;SubCategory.Crib.Shoes': 0,
#              'Closure.Lace.up;SubCategory.Firstwalker': 33,
#              'Closure.Lace.up;SubCategory.Flats': 13,
#              'Closure.Lace.up;SubCategory.Heel': 0,
#              'Closure.Lace.up;SubCategory.Heels': 131,
#              'Closure.Lace.up;SubCategory.Knee.High': 87,
#              'Closure.Lace.up;SubCategory.Loafers': 5,
#              'Closure.Lace.up;SubCategory.Mid.Calf': 804,
#              'Closure.Lace.up;SubCategory.Over.the.Knee': 1,
#              'Closure.Lace.up;SubCategory.Oxfords': 1901,
#              'Closure.Lace.up;SubCategory.Prewalker': 25,
#              'Closure.Lace.up;SubCategory.Prewalker.Boots': 1,
#              'Closure.Lace.up;SubCategory.Slipper.Flats': 15,
#              'Closure.Lace.up;SubCategory.Slipper.Heels': 0,
#              'Closure.Lace.up;SubCategory.Sneakers.and.Athletic.Shoes': 10113,
#              'Closure.Lace.up;ToeStyle.Algonquin': 44,
#              'Closure.Lace.up;ToeStyle.Almond': 82,
#              'Closure.Lace.up;ToeStyle.Apron Toe': 20,
#              'Closure.Lace.up;ToeStyle.Bicycle Toe': 126,
#              'Closure.Lace.up;ToeStyle.Bump Toe': 236,
#              'Closure.Lace.up;ToeStyle.Capped Toe': 921,
#              'Closure.Lace.up;ToeStyle.Center Seam': 35,
#              'Closure.Lace.up;ToeStyle.Closed Toe': 4226,
#              'Closure.Lace.up;ToeStyle.Medallion': 123,
#              'Closure.Lace.up;ToeStyle.Moc Toe': 858,
#              'Closure.Lace.up;ToeStyle.Open Toe': 25,
#              'Closure.Lace.up;ToeStyle.Peep Toe': 10,
#              'Closure.Lace.up;ToeStyle.Pointed Toe': 15,
#              'Closure.Lace.up;ToeStyle.Round Toe': 5379,
#              'Closure.Lace.up;ToeStyle.Snip Toe': 22,
#              'Closure.Lace.up;ToeStyle.Snub Toe': 48,
#              'Closure.Lace.up;ToeStyle.Square Toe': 108,
#              'Closure.Lace.up;ToeStyle.Wide Toe Box': 34,
#              'Closure.Lace.up;ToeStyle.Wingtip': 527,
#              'Closure.Monk.Strap;Closure.Pull.on': 0,
#              'Closure.Monk.Strap;Closure.Sling.Back': 0,
#              'Closure.Monk.Strap;Closure.Slip.On': 0,
#              'Closure.Monk.Strap;Closure.Snap': 0,
#              'Closure.Monk.Strap;Closure.Spat.Strap': 0,
#              'Closure.Monk.Strap;Closure.T.Strap': 0,
#              'Closure.Monk.Strap;Closure.Toggle': 0,
#              'Closure.Monk.Strap;Closure.Zipper': 0,
#              'Closure.Monk.Strap;Gender.Boys': 27,
#              'Closure.Monk.Strap;Gender.Girls': 2,
#              'Closure.Monk.Strap;Gender.Men': 42,
#              'Closure.Monk.Strap;Gender.Women': 13,
#              'Closure.Monk.Strap;HeelHeight.High.heel': 0,
#              ...})

# %%
G = nx.Graph()
for a_pair, wt in attr_pair_weight.items():
    a_1, a_2 = a_pair.split(";")
    G.add_edge(a_1, a_2, weight=wt)
print("no of connected components", G.number_connected_components())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-7b3d7c2bec82> in <module>
# ----> 1 G = nx.Graph()
#       2 for a_pair, wt in attr_pair_weight.items():
#       3     a_1, a_2 = a_pair.split(";")
#       4     G.add_edge(a_1, a_2, weight=wt)
#       5 print("no of connected components", G.number_connected_components())
#
# NameError: name 'nx' is not defined
