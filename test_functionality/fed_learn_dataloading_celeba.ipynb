# %%
import sys
sys.path.append('..')

# %%
import json
from src.data.fedlearn_datasets import FedDataset, FedDataLoader
import time
import matplotlib.pyplot as plt

# %%
n_shot_per_class = 1
n_query_per_class = 5
start = time.time()
fed_dataset = FedDataset(
        json_path='fed_data/celeba/val.json',
        image_size=(84, 84),
        n_shot_per_class=n_shot_per_class,
        n_query_per_class=n_query_per_class,
        randomize_query=True,
        preload=True)
end = time.time()
# Out:
# 100%|██████████| 1428/1428 [00:40<00:00, 34.98it/s]

# %%
fed_loader = FedDataLoader(dataset=fed_dataset,
                           n_batches=100,
                           batch_size=100)

# %%
start = time.time()
for a in fed_loader:
    print(a[0].shape)
end = time.time()
# Out:
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# torch.Size([100, 2, 3, 84, 84])
# ...

# %%
(end - start) / 100
# Out:
# 0.12559680938720702

# %%
print(a[2].shape)
# Out:
# torch.Size([100, 10, 3, 84, 84])

# %%
for i in range(5):
    for j in range(n_shot_per_class * 2):
        print(a[1][i][j])
        plt.imshow(a[0][i][j].permute(1, 2, 0))
        plt.show()
    
    for k in range(n_query_per_class * 2):
        print(a[3][i][k])
        plt.imshow(a[2][i][k].permute(1, 2, 0))
        plt.show()

    print('#' * 50)
# Out:
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# ##################################################
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# ##################################################
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# ##################################################
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# ##################################################
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# tensor(1)
# ##################################################
